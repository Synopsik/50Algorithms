# %%
from Chapter_1_3.sorting_algorithms import test_sort

bubble_sort = test_sort("bubble_sort")
insert_sort = test_sort("insert_sort")
merge_sort = test_sort("merge_sort")
shell_sort = test_sort("shell_sort")
selection_sort = test_sort("selection_sort")
# Out:
#  bubble_sort #1: 0.0004204964637756348
#  bubble_sort #2: 0.0018419313430786133
#  bubble_sort #3: 0.004448058605194091
#  bubble_sort #4: 0.008693675994873046
#  bubble_sort #5: 0.01371894359588623
#  bubble_sort #6: 0.020305299758911134
#  bubble_sort #7: 0.02856628894805908
#  bubble_sort #8: 0.03788968801498413
#  bubble_sort #9: 0.04916585922241211
#  bubble_sort #10: 0.06110799312591553
#  insert_sort #1: 0.00019013643264770508
#  insert_sort #2: 0.0006164622306823731
#  insert_sort #3: 0.0014023518562316895
#  insert_sort #4: 0.002623291015625
#  insert_sort #5: 0.004292418956756592
#  insert_sort #6: 0.006166667938232422
#  insert_sort #7: 0.008177065849304199
#  insert_sort #8: 0.011019713878631592
#  insert_sort #9: 0.013678791522979737
#  insert_sort #10: 0.017877724170684815
#  merge_sort #1: 9.507417678833007e-05
#  merge_sort #2: 0.00020520925521850587
#  merge_sort #3: 0.00031037569046020507
#  merge_sort #4: 0.0005255627632141113
# ...

# %%
from Chapter_1_3.plot_tool import plot

bub = ["Bubble Sort", bubble_sort, '.-']
ins = ["Insert Sort", insert_sort, '.-']
merge = ["Merge Sort", merge_sort, '.-']
shell = ["Shell Sort", shell_sort, '.-']
sel = ["Selection Sort", selection_sort, '.-']

alg_list = [
    #bub,
    ins,
    merge,
    shell,
    sel]

plot(alg_list)

# %%
# Out:
# 3000
